# %%
import pandas as pd
import pickle
from src.core import config, PACKAGE_ROOT, ASSETS_PATH

# %%
data = pd.read_csv(f'{PACKAGE_ROOT}/{config.ml_config.predict_data_path}')
data.head()
# Out:
#    IDADE_CLIENTE  RENDA_MENSAL_CLIENTE  BEHAVIOUR_SCORE_CLIENTE  \
# 0             30                 10485                       75
# 1             53                 16980                       85
# 2             56                 17670                       97
# 3             31                 10590                       86
# 4             26                  7590                       56
#
#    QTD_TRANSACOES_3M  QTD_ITENS_3M  VALOR_GASTO_3M  TICKET_MEDIO_3M  \
# 0                  2             5             517           258.50
# 1                  6             7            2237           372.83
# 2                  5             8            1174           234.80
# 3                  3             5            1381           460.33
# 4                  5             4            1129           225.80
#
#    FLAG_ELETRONICOS_3M SATISFACAO_ULTIMA_COMPRA
# 0                    0            02_Satisfeito
# 1                    0            Nao_Respondeu
# 2                    1                03_Neutro
# 3                    0                03_Neutro
# 4                    0      01_Muito_Satisfeito

# %%
len(data.columns)
# Out:
# 9

# %%
filename = f'{ASSETS_PATH}/{config.ml_config.production_model_file}'
load_model = pickle.load(open(filename, 'rb'))

# %%
load_model
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('quanti', StandardScaler(),
#                                                   ['IDADE_CLIENTE',
#                                                    'RENDA_MENSAL_CLIENTE',
#                                                    'BEHAVIOUR_SCORE_CLIENTE',
#                                                    'QTD_TRANSACOES_3M',
#                                                    'QTD_ITENS_3M',
#                                                    'VALOR_GASTO_3M',
#                                                    'TICKET_MEDIO_3M']),
#                                                  ('quali',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['FLAG_ELETRONICOS_3M',
#                                                    'SATISFACAO_ULTIMA_COMPRA'])])),
#                 ('linear regression',
#                  RandomizedSearchCV(cv=10, estimator=Ridge(),
#                                     param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x16a5de6f0>},
#                                     scoring='neg_root_mean_squared_log_error'))])

# %%
predictions = load_model.predict(data)

# %%
predictions[:10]
# Out:
# array([ 585.01066802, 5481.80487347, 4338.56539629, 2024.66241116,
#        3131.23903029, 5922.1677962 , 1844.42960003, 4679.04519593,
#        1789.04594654, 1586.45395631])
